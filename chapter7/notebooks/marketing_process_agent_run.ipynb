# %% [markdown]
# # Marketing Process Agent Runner
#
# このノートブックは、`src/marketing_process_agent/agent.py` に実装された MarketingProcessAgent クラスを用いてエージェントを実行します。

# %%
# 必要なモジュールのインポート
import sys
import os

# プロジェクトルートをパスに追加（必要に応じて調整してください）
sys.path.append(os.path.join(os.getcwd(), '../src/marketing_process_agent'))

from agent import MarketingProcessAgent  

# Instantiate the agent
agent = MarketingProcessAgent()

# Define a sample user request
user_request = (
    "生成AIエージェント実践講座のコンテンツマーケティングを計画してください。"
    "ターゲットは生成AIエージェントを活用して業務効率化を目指すビジネスパーソンです。"
)

# Run the agent
result = agent.run_agent(user_request)

# Display the result
print("最終実行結果:", result)
# Out:
# 2025-02-25 08:21:16,528 - agent - INFO - Plannerエージェント開始
# 2025-02-25 08:21:21,009 - agent - INFO - 生成された計画: [Plan(plan='生成AIエージェントを活用するビジネスパーソンのペルソナを作成し、具体的なニーズや課題を明確にする。', action_type='persona_create_task'), Plan(plan='生成AIエージェントを活用した業務効率化のカスタマージャーニーを作成し、各段階での顧客の行動や感情を把握する。', action_type='customer_journey_create_task'), Plan(plan='生成AIエージェントの導入事例や成功ストーリーをテーマにしたコンテンツ案を作成し、ターゲットの興味を引く。', action_type='contents_idea_create_task'), Plan(plan='生成AIエージェントの活用方法や具体的なツールの紹介をテーマにしたコンテンツ案を作成し、実践的な情報を提供する。', action_type='contents_idea_create_task'), Plan(plan='生成AIエージェントを活用した業務効率化のメリットとROIをテーマにしたコンテンツ案を作成し、導入の価値を伝える。', action_type='contents_idea_create_task')]
# 2025-02-25 08:21:21,012 - agent - INFO - Actorエージェント開始
# ...

# %% [markdown]
# ### Notes
#
# - Make sure your project environment is properly configured (e.g., Python path, environment variables, etc.).
# - The agent may perform calls to external services (such as JIRA or Azure OpenAI). Ensure you have valid credentials and connectivity.
# - You can adjust the `user_request` string to test different scenarios.
